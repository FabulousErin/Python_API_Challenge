# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities_new.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 585

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units=Imperial&q="

# %%
# Loop through the list of cities and perform a request for data on each

big_city_array = []
for city in cities:
    try:
        response = requests.get(query_url + city).json()

        lat = response['coord']['lat']
        lng = response['coord']['lon']
        temp = response['main']['temp']
        hum = response['main']['humidity']
        cld = response['clouds']['all']
        wind = response['wind']['speed']


        big_city_array.append({
            "City":city.title(),
            "Temp" : temp,
            "Lat" : lat,
            "Lng": lng,
            "Temp": temp,
            "Hum": hum,
            "Cloud": cld,
            "Wind": wind
        }) 

    except:
        print("City not found. Skipping")
        pass
# Out:
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# City not found. Skipping
# ...

# %%
len(big_city_array)
# Out:
# 535

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | yerbogachen
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | touba
# Processing Record 5 of Set 1 | jamestown
# Processing Record 6 of Set 1 | rio grande
# Processing Record 7 of Set 1 | ibra
# Processing Record 8 of Set 1 | port elizabeth
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | nemuro
# Processing Record 12 of Set 1 | morgan city
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | kawalu
# Processing Record 15 of Set 1 | hami
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | hjallerup
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | bengkulu
# Processing Record 21 of Set 1 | victoria
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df=pd.DataFrame(big_city_array)
weather_df["Hum"].head()
# Out:
# 0    27
# 1    80
# 2    70
# 3    70
# 4    82
# Name: Hum, dtype: int64

# %%
weather_df.describe()
# Out:
#              Temp         Lat         Lng         Hum       Cloud        Wind
# count  535.000000  535.000000  535.000000  535.000000  535.000000  535.000000
# mean    55.769570   19.665034   24.436698   69.123364   54.371963    8.696916
# std     28.602297   33.471843   92.951872   21.475614   39.914304    5.783823
# min    -31.740000  -54.800000 -179.166700    6.000000    0.000000    0.200000
# 25%     39.145000   -8.164600  -54.361800   60.000000    4.500000    4.610000
# 50%     62.600000   22.983300   27.666700   74.000000   70.000000    6.930000
# 75%     79.380000   47.391650  108.826650   85.000000   93.000000   12.035000
# max    107.650000   78.218600  179.316700  100.000000  100.000000   29.930000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
hum_df=weather_df.loc[weather_df["Hum"] > 100]
print(f'There are {len(hum_df)} number of cities with humidity over 100%.')
# Out:
# There are 0 number of cities with humidity over 100%.

# %%
quartiles = weather_df["Hum"].quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"The lower quartile of temperatures is: {lowerq}")
print(f"The upper quartile of temperatures is: {upperq}")
print(f"The interquartile range of temperatures is: {iqr}")
print(f"The the median of temperatures is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of temperatures is: 60.0
# The upper quartile of temperatures is: 85.0
# The interquartile range of temperatures is: 25.0
# The the median of temperatures is: 74.0
# Values below 22.5 could be outliers.
# Values above 122.5 could be outliers.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data_df=weather_df.loc[weather_df["Hum"] >= 16.5]
clean_city_data_df.head()
# Out:
#              City   Temp      Lat       Lng  Hum  Cloud   Wind
# 0       Salamiyah  72.72  35.0113   37.0532   27      0   5.64
# 1      Butaritari  81.37   3.0707  172.7902   80     59  13.82
# 2  Kulhudhuffushi  83.79   6.6221   73.0700   70     49   7.92
# 3          Barrow -14.80  71.2906 -156.7887   70      1  11.50
# 4    Christchurch  56.61 -43.5333  172.6333   82     90   4.61

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x_values = clean_city_data_df['Lat']
y_values = clean_city_data_df['Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
title = plt.title("Temperature vs Latitude")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x_values = clean_city_data_df['Lat']
y_values = clean_city_data_df['Hum']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
title = plt.title("Humidity vs Latitude")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x_values = clean_city_data_df['Lat']
y_values = clean_city_data_df['Cloud']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloud')
title = plt.title("Cloudiness vs Latitude")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x_values = clean_city_data_df['Lat']
y_values = clean_city_data_df['Wind']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind')
title = plt.title("Wind vs Latitude")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_df=clean_city_data_df.loc[clean_city_data_df['Lat']>=0]


x_values = northern_df['Lat']
y_values = northern_df['Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="black")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
title = plt.title("Northern Hemisphere Temperature vs Latitude")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_df=clean_city_data_df.loc[clean_city_data_df['Lat']<0]

x_values = southern_df['Lat']
y_values = southern_df['Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="black")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Temperature')
title = plt.title("Southern Hemisphere Temperature vs Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.5752646755004236

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Hum']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,18),fontsize=15,color="black")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
title = plt.title("Northern Hemisphere Humidity vs Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.05686079614231183

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Hum']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,28),fontsize=15,color="black")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
title = plt.title("Southern Hemisphere Humidity vs Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.0025776700097631102

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Cloud']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,22),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
title = plt.title("Northern Hemisphere Cloudiness vs Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.022309811760451822

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Cloud']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,7),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
title = plt.title("Southern Hemisphere Cloudiness vs Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.03503994602728193

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Wind']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,25),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
title = plt.title("Northern Hemisphere Wind vs Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.024528588506781038

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Wind']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.plot(x_values,regress_values,"r-")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
title = plt.title("Southern Hemisphere Wind vs Latitude")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.049158436782844615
